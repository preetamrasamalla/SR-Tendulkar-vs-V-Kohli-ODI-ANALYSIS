# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mat
import seaborn as sbn
import warnings
warnings.filterwarnings("ignore")

# %%
data= pd.read_csv('ODI_data.csv')

# %%
data
# Out:
#        Innings Player Innings Runs Scored Innings Runs Scored Num  \
# 0             E Lewis                  65                      65
# 1            N Pooran                  42                      42
# 2          SO Hetmyer                  18                      18
# 3            RL Chase                  18                      18
# 4         SS Cottrell                  17                      17
# ...               ...                 ...                     ...
# 171963     IR Redpath                 NaN                     NaN
# 171964    IM Chappell                 NaN                     NaN
# 171965     KD Walters                 NaN                     NaN
# 171966       RW Marsh                 NaN                     NaN
# 171967    GS Chappell                 NaN                     NaN
#
#        Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 0                         128                  1.0                   0.0
# ...

# %%
data.shape
# Out:
# (171968, 28)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171968 entries, 0 to 171967
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Innings Player                 171968 non-null  object
#  1   Innings Runs Scored            85984 non-null   object
#  2   Innings Runs Scored Num        85984 non-null   object
#  3   Innings Minutes Batted         85984 non-null   object
#  4   Innings Batted Flag            85984 non-null   float64
#  5   Innings Not Out Flag           85984 non-null   float64
#  6   Innings Balls Faced            85984 non-null   object
#  7   Innings Boundary Fours         85984 non-null   object
#  8   Innings Boundary Sixes         85984 non-null   object
#  9   Innings Batting Strike Rate    85984 non-null   object
#  10  Innings Number                 171968 non-null  object
#  11  Opposition                     171968 non-null  object
# ...

# %%
data.describe()
# Out:
#        Innings Batted Flag  Innings Not Out Flag          50's         100's  \
# count         85984.000000          85984.000000  85984.000000  85984.000000
# mean              0.786135              0.148074      0.097169      0.020143
# std               0.410035              0.355175      0.296190      0.140491
# min               0.000000              0.000000      0.000000      0.000000
# 25%               1.000000              0.000000      0.000000      0.000000
# 50%               1.000000              0.000000      0.000000      0.000000
# 75%               1.000000              0.000000      0.000000      0.000000
# max               1.000000              1.000000      1.000000      1.000000
#
#        Innings Bowled Flag     4 Wickets     5 Wickets  10 Wickets
# count         85984.000000  85984.000000  85984.000000     85984.0
# mean              0.537751      0.994476      0.005524         0.0
# std               0.498576      0.074120      0.074120         0.0
# ...

# %%
data.isnull().sum()
# Out:
# Innings Player                       0
# Innings Runs Scored              85984
# Innings Runs Scored Num          85984
# Innings Minutes Batted           85984
# Innings Batted Flag              85984
# Innings Not Out Flag             85984
# Innings Balls Faced              85984
# Innings Boundary Fours           85984
# Innings Boundary Sixes           85984
# Innings Batting Strike Rate      85984
# Innings Number                       0
# Opposition                           0
# Ground                               0
# Innings Date                         0
# Country                              0
# 50's                             85984
# 100's                            85984
# Innings Runs Scored Buckets      85984
# Innings Overs Bowled             85984
# Innings Bowled Flag              85984
# Innings Maidens Bowled           85984
# Innings Runs Conceded            85984
# Innings Wickets Taken            85984
# 4 Wickets                        85984
# ...

# %%
data.columnsIndex(['Innings Player', 'Innings Runs Scored', 'Innings Runs Scored Num',
# Out:
# Index(['Innings Player', 'Innings Runs Scored', 'Innings Runs Scored Num',
#        'Innings Minutes Batted', 'Innings Batted Flag', 'Innings Not Out Flag',
#        'Innings Balls Faced', 'Innings Boundary Fours',
#        'Innings Boundary Sixes', 'Innings Batting Strike Rate',
#        'Innings Number', 'Opposition', 'Ground', 'Innings Date', 'Country',
#        '50's', '100's', 'Innings Runs Scored Buckets', 'Innings Overs Bowled',
#        'Innings Bowled Flag', 'Innings Maidens Bowled',
#        'Innings Runs Conceded', 'Innings Wickets Taken', '4 Wickets',
#        '5 Wickets', '10 Wickets', 'Innings Wickets Taken Buckets',
#        'Innings Economy Rate'],
#       dtype='object')

# %%
data['Innings Runs Scored']
# Out:
# 0          65
# 1          42
# 2          18
# 3          18
# 4          17
#          ...
# 171963    NaN
# 171964    NaN
# 171965    NaN
# 171966    NaN
# 171967    NaN
# Name: Innings Runs Scored, Length: 171968, dtype: object

# %%
data.dtypes
# Out:
# Innings Player                    object
# Innings Runs Scored               object
# Innings Runs Scored Num           object
# Innings Minutes Batted            object
# Innings Batted Flag              float64
# Innings Not Out Flag             float64
# Innings Balls Faced               object
# Innings Boundary Fours            object
# Innings Boundary Sixes            object
# Innings Batting Strike Rate       object
# Innings Number                    object
# Opposition                        object
# Ground                            object
# Innings Date                      object
# Country                           object
# 50's                             float64
# 100's                            float64
# Innings Runs Scored Buckets       object
# Innings Overs Bowled              object
# Innings Bowled Flag              float64
# Innings Maidens Bowled            object
# Innings Runs Conceded             object
# Innings Wickets Taken             object
# ...

# %% [markdown]
# __-->"Changing the data types of 'Innings Runs Scored Num', 'Innings Balls Faced',Innings Number'"__

# %%
data['Innings Runs Scored Num']=pd.to_numeric(data['Innings Runs Scored Num'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File D:\lib\site-packages\pandas\_libs\lib.pyx:2315, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "-"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 data['Innings Runs Scored Num']=pd.to_numeric(data['Innings Runs Scored Num'])
#
# File D:\lib\site-packages\pandas\core\tools\numeric.py:184, in to_numeric(arg, errors, downcast)
#     182 coerce_numeric = errors not in ("ignore", "raise")
#     183 try:
# --> 184     values, _ = lib.maybe_convert_numeric(
#     185         values, set(), coerce_numeric=coerce_numeric
#     186     )
#     187 except (ValueError, TypeError):
#     188     if errors == "raise":
#
# ...

# %% [markdown]
# _we are getting this error because we are having an unknown value "-" in the entries we need to remove this for our convience_

# %%
data['Innings Runs Scored Num'].unique()
# Out:
# array(['65', '42', '18', '17', '13', '11', '5', '0', '120', '71', '20',
#        '16', '3', '2', '1', '-', nan, '40', '6', '4', '87', '54', '46',
#        '30', '12', '69', '39', '14', '10', '9', '8', '7', '82', '52',
#        '41', '15', '98', '43', '19', '111', '48', '36', '25', '67', '60',
#        '84', '59', '55', '47', '85', '49', '45', '34', '29', '22', '74',
#        '28', '77', '50', '32', '23', '35', '122', '100', '95', '103',
#        '113', '53', '96', '27', '64', '58', '33', '31', '73', '56', '86',
#        '62', '106', '24', '57', '104', '26', '66', '51', '118', '105',
#        '101', '21', '79', '44', '102', '88', '80', '72', '97', '68', '89',
#        '38', '83', '63', '148', '166', '90', '76', '37', '70', '124',
#        '94', '140', '153', '107', '117', '121', '92', '78', '75', '114',
#        '115', '130', '128', '151', '110', '138', '135', '109', '61',
#        '179', '170', '112', '116', '91', '143', '93', '123', '145', '81',
# ...

# %%
data=data[data['Innings Runs Scored Num']!="-"]

# %%
data.dropna(subset=['Innings Runs Scored Num'], inplace=True)

# %%
data
# Out:
#        Innings Player Innings Runs Scored  Innings Runs Scored Num  \
# 0             E Lewis                  65                     65.0
# 1            N Pooran                  42                     42.0
# 2          SO Hetmyer                  18                     18.0
# 3            RL Chase                  18                     18.0
# 4         SS Cottrell                  17                     17.0
# ...               ...                 ...                      ...
# 171937       WM Lawry                  27                     27.0
# 171938    GS Chappell                 22*                     22.0
# 171939   KR Stackpole                  13                     13.0
# 171940     IR Redpath                  12                     12.0
# 171941       RW Marsh                 10*                     10.0
#
#        Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 0                         128                  1.0                   0.0
# ...

# %%
## now after some cleaning process we go further for changing data types

# %%
data['Innings Runs Scored Num']=pd.to_numeric(data['Innings Runs Scored Num'])

# %%
data['Innings Balls Faced']=pd.to_numeric(data['Innings Balls Faced'])

# %%
data['Innings Number']=pd.to_numeric(data['Innings Number'])

# %%
## converting to date time series

data['Innings Date']= pd.to_datetime(data['Innings Date'])

data['year'] = pd.DatetimeIndex(data['Innings Date']).year

# %%
data.year.unique()
# Out:
# array([2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009,
#        2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000, 1999, 1998,
#        1997, 1996, 1995, 1994, 1993, 1992, 1991, 1990, 1989, 1988, 1987,
#        1986, 1985, 1984, 1983, 1982, 1981, 1980, 1979, 1978, 1977, 1976,
#        1975, 1974, 1973, 1972, 1971], dtype=int64)

# %% [markdown]
# ## Creating two new data sets one for Virat and Sachin each.
# _According to my reaserch on odi matches SACHIN TENDULKAR was active from 1994 to 2012,, & VIRAT KOHLI from 2008 to 2009 (according to data provided)_

# %%
sachin=data[(data.year>=1994)&(data.year<=2012)]
sachin
# Out:
#        Innings Player Innings Runs Scored  Innings Runs Scored Num  \
# 35112        MS Dhoni                113*                    113.0
# 35113        SK Raina                  43                     43.0
# 35114        R Ashwin                 31*                     31.0
# 35115       G Gambhir                   8                      8.0
# 35116        V Sehwag                   4                      4.0
# ...               ...                 ...                      ...
# 133835  MJ Greatbatch                  21                     21.0
# 133836      RT Latham                  11                     11.0
# 133837       AH Jones                   9                      9.0
# 133838      GR Larsen                  6*                      6.0
# 133839  KR Rutherford                   1                      1.0
#
#        Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 35112                     177                  1.0                   1.0
# ...

# %%
virat=data[(data.year>=2008)&(data.year<=2019)]
virat
# Out:
#       Innings Player Innings Runs Scored  Innings Runs Scored Num  \
# 0            E Lewis                  65                     65.0
# 1           N Pooran                  42                     42.0
# 2         SO Hetmyer                  18                     18.0
# 3           RL Chase                  18                     18.0
# 4        SS Cottrell                  17                     17.0
# ...              ...                 ...                      ...
# 60407       D Ramdin                   3                      3.0
# 60408       DJ Bravo                   2                      2.0
# 60409      R Rampaul                   2                      2.0
# 60410     FH Edwards                  0*                      0.0
# 60411     DBL Powell                   0                      0.0
#
#       Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 0                        128                  1.0                   0.0
# ...

# %%
##being more specifc for sachin we can create data set on basic of their name

# %%
sachin_df=data[data['Innings Player']=='SR Tendulkar']

# %%
sachin_df
# Out:
#        Innings Player Innings Runs Scored  Innings Runs Scored Num  \
# 37248    SR Tendulkar                  52                     52.0
# 37334    SR Tendulkar                 114                    114.0
# 37448    SR Tendulkar                   6                      6.0
# 37799    SR Tendulkar                  39                     39.0
# 37855    SR Tendulkar                  14                     14.0
# ...               ...                 ...                      ...
# 144603   SR Tendulkar                  20                     20.0
# 144691   SR Tendulkar                  10                     10.0
# 145010   SR Tendulkar                  36                     36.0
# 145193   SR Tendulkar                   0                      0.0
# 146018   SR Tendulkar                   0                      0.0
#
#        Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 37248                      93                  1.0                   0.0
# ...

# %%
virat_df=data[data['Innings Player']=='V Kohli']

# %%
virat_df
# Out:
#       Innings Player Innings Runs Scored  Innings Runs Scored Num  \
# 11           V Kohli                 120                    120.0
# 327          V Kohli                   1                      1.0
# 420          V Kohli                 34*                     34.0
# 664          V Kohli                  26                     26.0
# 804          V Kohli                  66                     66.0
# ...              ...                 ...                      ...
# 56848        V Kohli                  31                     31.0
# 56916        V Kohli                  54                     54.0
# 57038        V Kohli                  25                     25.0
# 57190        V Kohli                  37                     37.0
# 57260        V Kohli                  12                     12.0
#
#       Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 11                       179                  1.0                   0.0
# ...

# %% [markdown]
# ##TOTAL RUNS SCORED BY SACHIN and VIRAT FROM GIVEN DATA

# %%
s_r=sachin_df['Innings Runs Scored Num'].sum()
s_r
# Out:
# 18426.0

# %%
v_r=virat_df['Innings Runs Scored Num'].sum()
v_r
# Out:
# 11406.0

# %% [markdown]
# RUN-RATE PER INNINGS

# %%
virat_df['Innings Runs Scored Num'].sum()/len(virat_df)
# Out:
# 49.80786026200873

# %%
sachin_df['Innings Runs Scored Num'].sum()/len(sachin_df)
# Out:
# 40.76548672566372

# %% [markdown]
# STRIKE RATES

# %%
virat_df.columns
# Out:
# Index(['Innings Player', 'Innings Runs Scored', 'Innings Runs Scored Num',
#        'Innings Minutes Batted', 'Innings Batted Flag', 'Innings Not Out Flag',
#        'Innings Balls Faced', 'Innings Boundary Fours',
#        'Innings Boundary Sixes', 'Innings Batting Strike Rate',
#        'Innings Number', 'Opposition', 'Ground', 'Innings Date', 'Country',
#        '50's', '100's', 'Innings Runs Scored Buckets', 'Innings Overs Bowled',
#        'Innings Bowled Flag', 'Innings Maidens Bowled',
#        'Innings Runs Conceded', 'Innings Wickets Taken', '4 Wickets',
#        '5 Wickets', '10 Wickets', 'Innings Wickets Taken Buckets',
#        'Innings Economy Rate', 'year'],
#       dtype='object')

# %%
#virats
v_sr= v_r/virat_df['Innings Balls Faced'].sum()*100
v_sr
# Out:
# 93.03425774877651

# %%
##sachins
s_sr= s_r/sachin_df['Innings Balls Faced'].sum()*100
s_sr
# Out:
# 86.23578415313334

# %% [markdown]
# CENTURYS- 100'S

# %%
#sachins
sachin_df["100's"].sum()
# Out:
# 49.0

# %%
#virats
virat_df["100's"].sum()
# Out:
# 42.0

# %% [markdown]
# FIFTYS-50'S

# %%
sachin_df["50's"].sum()
# Out:
# 96.0

# %%
virat_df["50's"].sum()
# Out:
# 54.0

# %% [markdown]
# OVERALL IN TEAM CONTRIBUTION

# %%
sachin[sachin['Country']=='India']['Innings Runs Scored Num'].sum()
# Out:
# 121263.0

# %%
s_r
# Out:
# 18426.0

# %%
#sachins
s_r/sachin[sachin['Country']=='India']['Innings Runs Scored Num'].sum() *100
# Out:
# 15.195071868583163

# %%
#virats
v_r/virat[virat['Country']=='India']['Innings Runs Scored Num'].sum() *100
# Out:
# 16.189286626735175

# %% [markdown]
# COMPARING TOTAL RUNS OF BATSMENS

# %%
player_countri=sachin.groupby('Innings Player')['Innings Runs Scored Num'].sum().sort_values(ascending=False)

# %%
player_countri.head(10).plot(kind='bar', color ='deepskyblue');

# %%
player_countri=virat.groupby('Innings Player')['Innings Runs Scored Num'].sum().sort_values(ascending=False).head(10).plot(kind='bar', color='tomato')

# %% [markdown]
# COMPARING 100'S

# %%
sachin.groupby('Innings Player')["100's"].sum().sort_values(ascending=False).head(10).plot(kind='bar');

# %%
virat.groupby('Innings Player')["100's"].sum().sort_values(ascending=False).head(10).plot(kind='bar', color='black');

# %% [markdown]
# VIRATS YEAR WISE PERFORMANCE

# %%
virat.groupby('year')['Innings Runs Scored Num'].sum().plot(marker='v', mfc='r');

# %%
sachin.groupby('year')['Innings Runs Scored Num'].sum().plot(color ='black',marker='v', mfc='r');

# %% [markdown]
# PREMIUM PLAYER AWARD

# %%
#batsmen
data.groupby('Innings Player')['Innings Runs Scored Num'].sum().sort_values(ascending=False).head(5)
# Out:
# Innings Player
# SR Tendulkar        18426.0
# KC Sangakkara       13975.0
# RT Ponting          13589.0
# ST Jayasuriya       13364.0
# DPMD Jayawardene    12381.0
# Name: Innings Runs Scored Num, dtype: float64

# %%
data.groupby('Innings Player')["100's"].sum().sort_values(ascending=False).head(5)
# Out:
# Innings Player
# SR Tendulkar     49.0
# V Kohli          42.0
# RT Ponting       29.0
# ST Jayasuriya    28.0
# RG Sharma        27.0
# Name: 100's, dtype: float64

# %%
data.groupby('Innings Player')["50's"].sum().sort_values(ascending=False).head(5)
# Out:
# Innings Player
# SR Tendulkar      96.0
# KC Sangakkara     90.0
# JH Kallis         86.0
# Inzamam-ul-Haq    83.0
# RT Ponting        82.0
# Name: 50's, dtype: float64
